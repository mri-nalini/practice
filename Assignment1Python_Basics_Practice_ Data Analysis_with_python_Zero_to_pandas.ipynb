# %%
# Install the library
# !pip install jovian --upgrade --quiet
# Out:
#   Cell In[2], line 2
#     pip install jovian --upgrade --quiet
#         ^
# SyntaxError: invalid syntax

# %%
import jovian

# %%
project_name='python-practice-assignment'

# %%
# Capture and upload a snapshot
jovian.commit(project=project_name, privacy='secret', evironment=None)
# Out:
# [jovian] Please enter your API key ( from https://jovian.com/ ):
# API KEY: ········
# [jovian] Creating a new project "mri-nalini/python-practice-assignment"
# [jovian] Committed successfully! https://jovian.com/mri-nalini/python-practice-assignment
# 'https://jovian.com/mri-nalini/python-practice-assignment'

# %%
name = "mrinalini"

# %%
age = 30

# %%
has_android_phone = True

# %%
name, age, has_android_phone
# Out:
# ('mrinalini', 30, 1)

# %%
person = {"Name" :"mrinalini","Age" : 30,"Has_Android_Phone" :False}

# %%
person
# Out:
# {'Name': 'mrinalini', 'Age': 30, 'Has_Android_Phone': 1}

# %%
type(person)
# Out:
# dict

# %%
print("{} is aged {}, and owns an {}.".format(
    person["Name"], 
    person["Age"], 
    "Android phone" if person["Has_Android_Phone"] else "iPhone"
))
# Out:
# mrinalini is aged 30, and owns an iPhone.

# %%
for key,val in person.items():
    print(f'The key "{key}" has the value "{val}" of the type "{type(val)}"')
# Out:
# The key "Name" has the value "mrinalini" of the type "<class 'str'>"
# The key "Age" has the value "30" of the type "<class 'int'>"
# The key "Has_Android_Phone" has the value "False" of the type "<class 'bool'>"

# %%
# Problem 2 - Working with Lists

# %%
my_list = ["black",2,True]
print(my_list)
# Out:
# ['black', 2, True]

# %%
print('My favorite color is', my_list[0])
# Out:
# My favorite color is black

# %%
print('I have {} pet(s).'.format(my_list[1]))
# Out:
# I have 2 pet(s).

# %%
if True:
    print("I have previous programming experience")
else:
    print("I do not have previous programming experience")
# Out:
# I have previous programming experience

# %%
my_list.append(17)
print(my_list)
# Out:
# ['black', 2, True, 17]

# %%
my_list.pop(0)
print(my_list)
# Out:
# [2, True, 17]

# %%
print("The list has {} elements.".format(len(my_list)))
# Out:
# The list has 3 elements.

# %%
jovian.commit(project=project_name,environment=None)
# Out:
# [jovian] Updating notebook "mri-nalini/python-practice-assignment" on https://jovian.com/
# [jovian] Committed successfully! https://jovian.com/mri-nalini/python-practice-assignment
# 'https://jovian.com/mri-nalini/python-practice-assignment'

# %%
#Problem 3 - Conditions and loops

# %%
# Q10: Calculate and display the sum of all the numbers divisible by 7 between 18 and 534 i.e. 21+28+35+...+525+532.

# %%
s=0
for i in range(18,534):
    if i %7==0:
        s+=i
print(s)
# Out:
# 20461

# %%
print('The sum of all the numbers divisible by 7 between 18 and 534 is', s)
# Out:
# The sum of all the numbers divisible by 7 between 18 and 534 is 20461

# %%
jovian.commit(project=project_name,environment=None)
# Out:
# [jovian] Updating notebook "mri-nalini/python-practice-assignment" on https://jovian.com/
# [jovian] Committed successfully! https://jovian.com/mri-nalini/python-practice-assignment
# 'https://jovian.com/mri-nalini/python-practice-assignment'

# %%
# Problem 4 - Flying to the Bahamas

# %% [markdown]
# Q11: A travel company wants to fly a plane to the Bahamas. Flying the plane costs 5000 dollars. So far, 29 people have signed up for the trip. If the company charges 200 dollars per ticket, what is the profit made by the company?

# %%
cost_of_flying_plane = 5000

# %%
number_of_passengers = 29

# %%
price_of_ticket = 200

# %%
profit =  (29 * 200) - 5000
print(profit)
# Out:
# 800

# %%
print("the company makes profit of {} dollars" .format(profit))
# Out:
# the company makes profit of 800 dollars

# %% [markdown]
# Q11b (Optional): Out of the 29 people who took the flight, only 12 buy tickets to return from the Bahamas on the same plane. If the flying the plane back also costs 5000 dollars, and does the company make an overall profit or loss? The company charges the same fee of 200 dollars per ticket for the return flight.

# %%
returning_passengers =12
total_profit_loss = ((29+12)*200)-10000
print(total_profit_loss)
# Out:
# -1800

# %%
# this is optional
if total_profit_loss>=0:
    print("The company makes an overall profit of {} dollars".format(total_profit_loss))
else:
    print("The company makes an overall loss of {} dollars".format(total_profit_loss))
# Out:
# The company makes an overall loss of -1800 dollars

# %%
jovian.commit(project=project_name,environment=None)
# Out:
# [jovian] Updating notebook "mri-nalini/python-practice-assignment" on https://jovian.com/
# [jovian] Committed successfully! https://jovian.com/mri-nalini/python-practice-assignment
# 'https://jovian.com/mri-nalini/python-practice-assignment'

# %% [markdown]
# Problem 5 - Twitter Sentiment Analysis

# %%
tweets = [
    "Wow, what a great day today!! #sunshine",
    "I feel sad about the things going on around us. #covid19",
    "I'm really excited to learn Python with @JovianML #zerotopandas",
    "This is a really nice song. #linkinpark",
    "The python programming language is useful for data science",
    "Why do bad things happen to me?",
    "Apple announces the release of the new iPhone 12. Fans are excited.",
    "Spent my day with family!! #happy",
    "Check out my blog post on common string operations in Python. #zerotopandas",
    "Freecodecamp has great coding tutorials. #skillup"
]

# %% [markdown]
# Q12: How many tweets does the dataset contain?

# %%
number_of_tweets = len(tweets)
print(number_of_tweets)
# Out:
# 10

# %%
happy_words = ['great', 'excited', 'happy', 'nice', 'wonderful', 'amazing', 'good', 'best']

# %%
sad_words = ['sad', 'bad', 'tragic', 'unhappy', 'worst']

# %%
sample_tweet = tweets[0]

# %%
sample_tweet
# Out:
# 'Wow, what a great day today!! #sunshine'

# %%
is_tweet_happy = False

# Get a word from happy_words
for word in happy_words:
    # Check if the tweet contains the word
    if word in sample_tweet:
        # Word found! Mark the tweet as happy
        is_tweet_happy = True

# %%
is_tweet_happy
# Out:
# True

# %% [markdown]
# **Q13: Determine the number of tweets in the dataset that can be classified as happy.**
#
# *Hint*: You'll need to use a loop inside another loop to do this. Use the code from the example shown above.

# %%
# store the final answer in this variable
number_of_happy_tweets = 0

# perform the calculations here
for i in range(0,len(tweets)):
    for word in happy_words:
        if word in tweets[i]:
            is_tweet_happy = True
            number_of_happy_tweets+=1

# %%
print("Number of happy tweets:", number_of_happy_tweets)
# Out:
# Number of happy tweets: 6

# %% [markdown]
# **Q14: What fraction of the total number of tweets are happy?**
#
# For example, if 2 out of 10 tweets are happy, then the answer is `2/10` i.e. `0.2`.

# %%
happy_fraction = number_of_happy_tweets / len(tweets)
print("The fraction of happy tweets is:", happy_fraction)
# Out:
# The fraction of happy tweets is: 0.6

# %% [markdown]
# To identify whether a tweet is sad, we can simply check if contains any of the words from `sad_words`.
#
# **Q15: Determine the number of tweets in the dataset that can be classified as sad.**

# %%
sad_fraction = number_of_sad_tweets/len(tweets)
print("The fraction of sad tweets is:", sad_fraction)
# store the final answer in this variable
number_of_sad_tweets = 0

# perform the calculations here
for i in range(0,len(tweets)):
    for word in sad_words:
        if word in tweets[i]:
            is_tweet_sad = True
            number_of_sad_tweets+=1
print("Number of sad tweets:", number_of_sad_tweets)
# Out:
# The fraction of sad tweets is: 0.2
# Number of sad tweets: 2

# %%
jovian.commit(project=project_name,environment=None)
# Out:
# [jovian] Updating notebook "mri-nalini/python-practice-assignment" on https://jovian.com/
# [jovian] Committed successfully! https://jovian.com/mri-nalini/python-practice-assignment
# 'https://jovian.com/mri-nalini/python-practice-assignment'

# %% [markdown]
# Q16b (Optional): Calculate the sentiment score, which is defined as the difference betweek the fraction of happy tweets and the fraction of sad tweets.

# %%
sentiment_score = happy_fraction - sad_fraction
print("The sentiment score for the given tweets is", sentiment_score)
# Out:
# The sentiment score for the given tweets is 0.39999999999999997

# %% [markdown]
# Q16c (Optional): Display whether the overall sentiment of the given dataset of tweets is happy or sad, using the sentiment score.

# %%
if sentiment_score > 0:
    print("The overall sentiment is happy")
else:
    print("The overall sentiment is sad")
# Out:
# The overall sentiment is happy

# %% [markdown]
# Q16d (Optional): What is the fraction of tweets that are neutral i.e. neither happy nor sad.

# %%
# store the final answer in this variable
number_of_neutral_tweets = 0

# perform the calculation here
number_of_neutral_tweets = len(tweets) - number_of_happy_tweets -  number_of_sad_tweets
print('The fraction of neutral tweets is', number_of_neutral_tweets)
# Out:
# The fraction of neutral tweets is 2

# %%
jovian.commit(project=project_name,environment=None)
# Out:
# [jovian] Updating notebook "mri-nalini/python-practice-assignment" on https://jovian.com/
# [jovian] Committed successfully! https://jovian.com/mri-nalini/python-practice-assignment
# 'https://jovian.com/mri-nalini/python-practice-assignment'
